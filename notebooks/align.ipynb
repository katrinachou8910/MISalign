# %% [markdown]
# # Imports

# %%
from sys import path as syspath
syspath.append("..")

# %%
from MISalign.model.mis_file import MisFile,save_mis,load_mis
from MISalign.alignment.interactive_manual import IMRControls

# %% [markdown]
# # Basic Alignment

# %%
mis_filepath = "../example/data/set_a/mymis_calibrated.mis"
mis_project=load_mis(mis_filepath)

# %%
# %matplotlib widget
imrc = IMRControls(mis_project)
# Out:
# VBox(children=(HBox(children=(Dropdown(description='Image A:', options=('a_myimages08.jpg', 'a_myimages09.jpg'…
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/GitHub/MISalign/MISalign-copy/notebooks/../MISalign/alignment/interactive_manual.py:131, in IMRControls.click_resolve(self, event)
#     130 def click_resolve(self,event):
# --> 131     self.imr.relate_resolve()
#     132     self.imr.plot_points()
#
# File ~/Documents/GitHub/MISalign/MISalign-copy/notebooks/../MISalign/alignment/interactive_manual.py:70, in InteractiveManualRelation.relate_resolve(self)
#      68     self.points=[(a,b) for a,b in zip(rel_pts[0],rel_pts[1])]#convert from list of x,y sorted by image to pairs of x,y pairs
#      69 else:
# ---> 70     raise ValueError("Mismatched number of selected points.")
#
# ValueError: Mismatched number of selected points.

# %%
# retrieve project with updated image relations from imrc
mis_project=imrc.get_mis()
print(mis_project)

# %%
del imrc._images #free up memory if needed

# %%
# save updated mis project with image relations
save_mis(mis_filepath,mis_project)
