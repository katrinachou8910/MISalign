# %% [markdown]
# # Imports

# %%
from sys import path as syspath
syspath.append("..")

# %%
from MISalign.model.mis_file import MisFile,save_mis,load_mis
from MISalign.alignment.interactive_manual import IMRControls

# %% [markdown]
# # Basic Alignment

# %%
mis_filepath = "../example/data/set_a/mymis.mis"
mis_project=load_mis(mis_filepath)

# %%
# %matplotlib widget
imrc = IMRControls(mis_project)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 get_ipython().run_line_magic('matplotlib', 'widget')
# ----> 2 imrc = IMRControls(mis_project)
#
# File ~/Documents/GitHub/MISalign/MISalign-copy/notebooks/../MISalign/alignment/interactive_manual.py:78, in IMRControls.__init__(self, mis_project)
#      76 def __init__(self,mis_project:MisFile):
#      77     self._project=mis_project
# ---> 78     self._images=[Image(x) for x in self._project.get_image_paths().values()]
#      79     self.names=[x.name for x in self._images]
#      80     ## setup dropdowns
#
# File ~/Documents/GitHub/MISalign/MISalign-copy/notebooks/../MISalign/model/image.py:12, in Image.__init__(self, image_fp)
#      10 self.image_fp=image_fp
#      11 self.name=split(image_fp)[1]
# ---> 12 PIL_image=PILImage.open(image_fp)
#      13 self.image=PIL_image.convert("RGB")
#      14 self.size=self.image.size
#
# File ~/Documents/GitHub/MISalign/MISalign-copy/.venv/lib/python3.13/site-packages/PIL/Image.py:3505, in open(fp, mode, formats)
#    3502     filename = os.fspath(fp)
#    3504 if filename:
# -> 3505     fp = builtins.open(filename, "rb")
#    3506     exclusive_fp = True
#    3507 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\example\\data\\set_a\\a_myimages01.jpg'

# %%
# retrieve project with updated image relations from imrc
mis_project=imrc.get_mis()
print(mis_project)

# %%
del imrc._images #free up memory if needed

# %%
# save updated mis project with image relations
save_mis(mis_filepath,mis_project)
