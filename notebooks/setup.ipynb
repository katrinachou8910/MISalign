# %% [markdown]
# # Imports

# %%
from sys import path as syspath
syspath.append("..")

# %%
from os import listdir
from os.path import join, abspath
from MISalign.model.mis_file import MisFile,save_mis

# %% [markdown]
# from os import listdir

# %%
###
# Enter setup information
###
folder_path = "../example/data/set_a" # folder with images
misfile_name="mymis_calibrated.mis" # name for save file
#
calibration_filepath = abspath("../example/data/set_a/a_5x.miscal") # filepath to calibration file `.miscal`
    # Important: If you do not have a calibration file then uncomment the next line
# calibration_filepath=None
#
file_ending="jpg" # file extension
file_contains="" # file names must contain - i.e. "sample1-5x", "sample2", "10x", etc.
file_notcontains="" # file names must not contain - i.e. "calibration"
#TODO Change not contains to a list of strings to check against.
###

# %%
mis_filepath=abspath(join(folder_path,misfile_name))
print(f"Save file filepath: {mis_filepath}")
file_names=[x for x in listdir(folder_path) if x.split(".")[-1]==file_ending]
if file_contains != "":
    file_names=[x for x in file_names if file_contains in x]
if file_notcontains != "":
    file_names=[x for x in file_names if file_notcontains not in x]
file_paths=[abspath(join(folder_path,x)) for x in file_names]
print("\n  ".join(["Image files and filepaths:"]+[f"{fn}: {fp}" for fn,fp in zip(file_names,file_paths)]))
if calibration_filepath is not None:
    print(f"Calibration file filepath: {calibration_filepath}")
# Out:
# Save file filepath: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/mymis_calibrated.mis
# Image files and filepaths:
#   a_myimages08.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages08.jpg
#   a_myimages09.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages09.jpg
#   a_myimages01.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages01.jpg
#   a_myimages02.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages02.jpg
#   a_myimages03.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages03.jpg
#   a_myimages07.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages07.jpg
#   a_myimages06.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages06.jpg
#   a_myimages04.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages04.jpg
#   a_myimages10.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages10.jpg
#   a_myimages05.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages05.jpg
# Calibration file filepath: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_5x.miscal

# %%
mis_project=MisFile(image_fps=file_paths,calibration_fp=calibration_filepath)
print(mis_project)
# Out:
# A MISalign project with:[['/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages08.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages09.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages01.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages02.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages03.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages07.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages06.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages04.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages10.jpg', '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages05.jpg'], [], {'pixel': 599.006361608906, 'length': 1, 'length_unit': 'mm'}]

# %%
save_mis(mis_filepath,mis_project)

# %% [markdown]
# # Advanced Setups

# %% [markdown]
# ## Image Sets

# %%
###
# Enter setup information
###
folder_path = "../example/data/set_a" # folder with images
misfile_names=["mymis1.mis","mymis2.mis"] # name for save file
#
file_ending="jpg" # file extension
file_contains="" # file names must contain - i.e. "sample1-5x", "sample2", "10x", etc.
file_notcontains="" # file names must not contain - i.e. "calibration"
###

# %%
mis_filepaths=[abspath(join(folder_path,x)) for x in misfile_names]
mis_dict={mn:mp for mn,mp in zip(misfile_names,mis_filepaths)}
print("\n  ".join(["Save files and filepaths: "]+[f"{mn}: {mp}" for mn,mp in zip(misfile_names,mis_filepaths)]))
file_names = [x for x in listdir(folder_path) if x.split(".")[-1] == file_ending]
# (possibly filtered more...)
file_paths = [abspath(join(folder_path, x)) for x in file_names]

if file_contains != "":
    file_names=[x for x in file_names if file_contains in x]
if file_notcontains != "":
    file_names=[x for x in file_names if file_notcontains not in x]
file_paths=[abspath(join(folder_path,x)) for x in file_names]
print("\n  ".join(["Image index, file names, and filepaths:"]+[f"{i} - {fn}: {fp}" for i,(fn,fp) in enumerate(zip(file_names,file_paths))]))
# Out:
# Save files and filepaths:
#   mymis1.mis: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/mymis1.mis
#   mymis2.mis: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/mymis2.mis
# Image index, file names, and filepaths:
#   0 - a_myimages08.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages08.jpg
#   1 - a_myimages09.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages09.jpg
#   2 - a_myimages01.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages01.jpg
#   3 - a_myimages02.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages02.jpg
#   4 - a_myimages03.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages03.jpg
#   5 - a_myimages07.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages07.jpg
#   6 - a_myimages06.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages06.jpg
#   7 - a_myimages04.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages04.jpg
#   8 - a_myimages10.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages10.jpg
#   9 - a_myimages05.jpg: /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages05.jpg

# %%
# user selected image sets using start and end index
image_sets={
    "mymis1.mis":(0,4),
    "mymis2.mis":(5,9),
}
for key,value in image_sets.items():
    print(key,file_names[value[0]:value[1]+1])
# Out:
# mymis1.mis ['a_myimages08.jpg', 'a_myimages09.jpg', 'a_myimages01.jpg', 'a_myimages02.jpg', 'a_myimages03.jpg']
# mymis2.mis ['a_myimages07.jpg', 'a_myimages06.jpg', 'a_myimages04.jpg', 'a_myimages10.jpg', 'a_myimages05.jpg']

# %%
for key,value in image_sets.items():
    mis_fp=mis_dict[key]
    print(mis_fp,"\n  ",file_names[value[0]:value[1]+1])
    mis_project=MisFile(image_fps=file_paths[value[0]:value[1]+1])
    save_mis(mis_fp,mis_project)
# Out:
# /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/mymis1.mis
#    ['a_myimages08.jpg', 'a_myimages09.jpg', 'a_myimages01.jpg', 'a_myimages02.jpg', 'a_myimages03.jpg']
# /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/mymis2.mis
#    ['a_myimages07.jpg', 'a_myimages06.jpg', 'a_myimages04.jpg', 'a_myimages10.jpg', 'a_myimages05.jpg']

# %% [markdown]
# ## SEM Trim & Convert
# For trimming footer of SEM images and converting into uint8/RGB which is presently needed for further processing

# %%
#TODO Remove need for RGB/uint8 conversion

# %%
from sys import path as syspath
syspath.append("..")

# %%
from MISalign.model.mis_file import load_mis
from PIL import Image as PILImage
import numpy as np
from shutil import copy2
from os.path import split, join
from os import mkdir

# %%
mis_fp = "../example/data/set_a/mymis1.mis"
mis_project = load_mis(mis_fp)
mis_image_paths = mis_project.get_image_paths()
mis_image_paths
# Out:
# {'a_myimages08.jpg': '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages08.jpg',
#  'a_myimages09.jpg': '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages09.jpg',
#  'a_myimages01.jpg': '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages01.jpg',
#  'a_myimages02.jpg': '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages02.jpg',
#  'a_myimages03.jpg': '/Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages03.jpg'}

# %%
split_mis_fp=split(mis_fp)
original_image_folder=join(split_mis_fp[0],"original_images")
from os.path import exists
from os import mkdir

if not exists(original_image_folder):
    mkdir(original_image_folder)
for img_name, img_fp in mis_image_paths.items():
    split_img_fp=split(img_fp)
    copy_img_fp=join(original_image_folder,split_img_fp[1])
    print(img_fp," > ",copy_img_fp)
    copy2(img_fp,copy_img_fp)
# Out:
# /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages08.jpg  >  ../example/data/set_a/original_images/a_myimages08.jpg
# /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages09.jpg  >  ../example/data/set_a/original_images/a_myimages09.jpg
# /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages01.jpg  >  ../example/data/set_a/original_images/a_myimages01.jpg
# /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages02.jpg  >  ../example/data/set_a/original_images/a_myimages02.jpg
# /Users/katrinachou/Documents/GitHub/MISalign/MISalign-copy/example/data/set_a/a_myimages03.jpg  >  ../example/data/set_a/original_images/a_myimages03.jpg

# %%
pixels_to_trim=248
for img_name, img_fp in mis_image_paths.items():
    img_arr=np.asarray(PILImage.open(img_fp))
    if img_arr.dtype=="uint16":
        img_arr=(img_arr//256).astype(np.uint8)
    img_arr_trimmed=img_arr[:-248]
    img_corrected=PILImage.fromarray(img_arr_trimmed).convert('RGB')
    img_corrected.save(img_fp)
